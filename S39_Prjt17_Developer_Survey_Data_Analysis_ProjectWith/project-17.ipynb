# %%
import pandas as pd
data =pd.read_csv('survey_results_public.csv')
data
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
data.shape
# Out:
# (89184, 84)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89184 entries, 0 to 89183
# Data columns (total 84 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   ResponseId                           89184 non-null  int64
#  1   Q120                                 89184 non-null  object
#  2   MainBranch                           89184 non-null  object
#  3   Age                                  89184 non-null  object
#  4   Employment                           87898 non-null  object
#  5   RemoteWork                           73810 non-null  object
#  6   CodingActivities                     73764 non-null  object
#  7   EdLevel                              87973 non-null  object
#  8   LearnCode                            87663 non-null  object
#  9   LearnCodeOnline                      70084 non-null  object
#  10  LearnCodeCoursesCert                 37076 non-null  object
# ...

# %%
pd.set_option('display.max_columns', 85)
data
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
#546. Basic Operations On DataSet

data['Employment']
# Out:
# 0                                                      NaN
# 1                                      Employed, full-time
# 2                                      Employed, full-time
# 3                                      Employed, full-time
# 4        Employed, full-time;Independent contractor, fr...
#                                ...
# 89179    Employed, full-time;Independent contractor, fr...
# 89180               Student, full-time;Employed, part-time
# 89181                                  I prefer not to say
# 89182               Employed, part-time;Student, part-time
# 89183                                  Employed, full-time
# Name: Employment, Length: 89184, dtype: object

# %%
data.Employment.value_counts()
# Out:
# Employment
# Employed, full-time                                                                                                                  53748
# Student, full-time                                                                                                                    7430
# Independent contractor, freelancer, or self-employed                                                                                  7076
# Employed, full-time;Independent contractor, freelancer, or self-employed                                                              4354
# Not employed, but looking for work                                                                                                    2553
#                                                                                                                                      ...
# Independent contractor, freelancer, or self-employed;Student, full-time;Student, part-time;Not employed, and not looking for work        1
# ...

# %%
data['OpSysProfessional use'].value_counts()
# Out:
# OpSysProfessional use
# Windows                                                                                  15943
# MacOS                                                                                    12928
# Ubuntu                                                                                    5201
# Windows;Windows Subsystem for Linux (WSL)                                                 3934
# Ubuntu;Windows                                                                            2795
#                                                                                          ...
# BSD;Fedora;MacOS;Red Hat;Solaris                                                             1
# AIX;Android;iOS;iPadOS;MacOS;Red Hat;Ubuntu;Windows;Windows Subsystem for Linux (WSL)        1
# AIX;Android;Ubuntu;Windows;Windows Subsystem for Linux (WSL)                                 1
# BSD;Debian;Windows                                                                           1
# ...

# %%
data.Employment[89182]
# Out:
# 'Employed, part-time;Student, part-time'

# %%
data['DevType']
# Out:
# 0                                         NaN
# 1        Senior Executive (C-Suite, VP, etc.)
# 2                         Developer, back-end
# 3                        Developer, front-end
# 4                       Developer, full-stack
#                          ...
# 89179                    Developer, front-end
# 89180                     Developer, back-end
# 89181                                     NaN
# 89182                    System administrator
# 89183                   Developer, full-stack
# Name: DevType, Length: 89184, dtype: object

# %%
data['DevType'].value_counts()
# Out:
# DevType
# Developer, full-stack                            25735
# Developer, back-end                              13745
# Developer, front-end                              5071
# Developer, desktop or enterprise applications     3904
# Other (please specify):                           3080
# Developer, mobile                                 2597
# Engineering manager                               2033
# Student                                           1996
# Developer, embedded applications or devices       1845
# Data scientist or machine learning specialist     1588
# DevOps specialist                                 1387
# Academic researcher                               1354
# Research & Development role                       1353
# Senior Executive (C-Suite, VP, etc.)              1332
# Engineer, data                                    1248
# Cloud infrastructure engineer                     1036
# Developer, game or graphics                        866
# ...

# %%
mac_user =data[data['OpSysProfessional use']=="MacOS"]

# %%
mac_user
# Out:
#        ResponseId     Q120                      MainBranch  \
# 5               6  I agree  I am a developer by profession
# 6               7  I agree  I am a developer by profession
# 16             17  I agree  I am a developer by profession
# 17             18  I agree  I am a developer by profession
# 20             21  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89134       89135  I agree     I code primarily as a hobby
# 89141       89142  I agree  I am a developer by profession
# 89153       89154  I agree  I am a developer by profession
# 89155       89156  I agree  I am a developer by profession
# 89156       89157  I agree  I am a developer by profession
#
#                       Age           Employment  \
# 5         35-44 years old  Employed, full-time
# 6         35-44 years old  Employed, full-time
# 16        35-44 years old  Employed, full-time
# 17        25-34 years old  Employed, full-time
# ...

# %%
#547. Using Multiple Queries
#find out the number of developers across every country
data['Country'].value_counts()
# Out:
# Country
# United States of America                                18647
# Germany                                                  7328
# India                                                    5625
# United Kingdom of Great Britain and Northern Ireland     5552
# Canada                                                   3507
#                                                         ...
# Saint Kitts and Nevis                                       1
# Samoa                                                       1
# Marshall Islands                                            1
# Central African Republic                                    1
# San Marino                                                  1
# Name: count, Length: 185, dtype: int64

# %%
# let's say you want to go ahead and classify the developers and want to perform analysis on developers only across a single country.
us_devlepr=data[data['Country']=='United States of America']

# %%
us_devlepr
# Out:
#        ResponseId     Q120                                         MainBranch  \
# 1               2  I agree                     I am a developer by profession
# 2               3  I agree                     I am a developer by profession
# 3               4  I agree                     I am a developer by profession
# 6               7  I agree                     I am a developer by profession
# 7               8  I agree                     I am a developer by profession
# ...           ...      ...                                                ...
# 89150       89151  I agree  I used to be a developer by profession, but no...
# 89154       89155  I agree                     I am a developer by profession
# 89156       89157  I agree                     I am a developer by profession
# 89175       89176  I agree                     I am a developer by profession
# 89178       89179  I agree                     I am a developer by profession
#
# ...

# %%
india_devlepr=data[data['Country']=='India']

# %%
india_devlepr
# Out:
#        ResponseId     Q120                                         MainBranch  \
# 9              10  I agree                     I am a developer by profession
# 66             67  I agree                     I am a developer by profession
# 78             79  I agree                     I am a developer by profession
# 82             83  I agree                     I am a developer by profession
# 85             86  I agree                     I am a developer by profession
# ...           ...      ...                                                ...
# 89119       89120  I agree                     I am a developer by profession
# 89121       89122  I agree  I am not primarily a developer, but I write co...
# 89164       89165  I agree                     I am a developer by profession
# 89165       89166  I agree                     I am a developer by profession
# 89167       89168  I agree                     I am a developer by profession
#
# ...

# %%
us_devlepr['Age'].value_counts()
# Out:
# Age
# 25-34 years old       6283
# 35-44 years old       4855
# 18-24 years old       2468
# 45-54 years old       2277
# 55-64 years old       1238
# Under 18 years old     867
# 65 years or older      529
# Prefer not to say      130
# Name: count, dtype: int64

# %%
us_devlepr['RemoteWork'].value_counts()
# Out:
# RemoteWork
# Remote                                  8889
# Hybrid (some remote, some in-person)    5179
# In-person                               2058
# Name: count, dtype: int64

# %%
india_devlepr['Age'].value_counts()
# Out:
# Age
# 18-24 years old       2296
# 25-34 years old       2289
# 35-44 years old        512
# Under 18 years old     378
# 45-54 years old        107
# 55-64 years old         20
# Prefer not to say       19
# 65 years or older        4
# Name: count, dtype: int64

# %%
india_devlepr['RemoteWork'].value_counts()
# Out:
# RemoteWork
# Hybrid (some remote, some in-person)    1638
# Remote                                  1405
# In-person                               1104
# Name: count, dtype: int64

# %%
#But let's say you want to go ahead and find out data which includes multiple conditions.
# let's suppose you want to find out how many number of people from India are actually interested in coding as a hobby.
#here in order to find that out.
data[data['CodingActivities']=="Hobby"]
# Out:
#        ResponseId     Q120                      MainBranch              Age  \
# 3               4  I agree  I am a developer by profession  25-34 years old
# 7               8  I agree  I am a developer by profession  25-34 years old
# 10             11  I agree  I am a developer by profession  25-34 years old
# 11             12  I agree  I am a developer by profession  25-34 years old
# 14             15  I agree  I am a developer by profession  25-34 years old
# ...           ...      ...                             ...              ...
# 89158       89159  I agree  I am a developer by profession  25-34 years old
# 89160       89161  I agree  I am a developer by profession  25-34 years old
# 89161       89162  I agree  I am a developer by profession  25-34 years old
# 89171       89172  I agree  I am a developer by profession  25-34 years old
# 89178       89179  I agree  I am a developer by profession  45-54 years old
#
# ...

# %%
data[(data['Country']=="India") & (data['CodingActivities']=="Hobby")]
# Out:
#        ResponseId     Q120                      MainBranch              Age  \
# 78             79  I agree  I am a developer by profession  18-24 years old
# 82             83  I agree  I am a developer by profession  25-34 years old
# 172           173  I agree  I am a developer by profession  18-24 years old
# 397           398  I agree  I am a developer by profession  18-24 years old
# 404           405  I agree  I am a developer by profession  25-34 years old
# ...           ...      ...                             ...              ...
# 87486       87487  I agree  I am a developer by profession  18-24 years old
# 87526       87527  I agree  I am a developer by profession  35-44 years old
# 87654       87655  I agree  I am a developer by profession  35-44 years old
# 87724       87725  I agree  I am a developer by profession  18-24 years old
# 88037       88038  I agree  I am a developer by profession  18-24 years old
#
# ...

# %%
data[(data['Country']=="India") & (data['CodingActivities']=="Hobby") & (data['Employment']=="Employed, full-time")]
# Out:
#        ResponseId     Q120                      MainBranch              Age  \
# 78             79  I agree  I am a developer by profession  18-24 years old
# 82             83  I agree  I am a developer by profession  25-34 years old
# 172           173  I agree  I am a developer by profession  18-24 years old
# 397           398  I agree  I am a developer by profession  18-24 years old
# 404           405  I agree  I am a developer by profession  25-34 years old
# ...           ...      ...                             ...              ...
# 87460       87461  I agree  I am a developer by profession  25-34 years old
# 87486       87487  I agree  I am a developer by profession  18-24 years old
# 87526       87527  I agree  I am a developer by profession  35-44 years old
# 87724       87725  I agree  I am a developer by profession  18-24 years old
# 88037       88038  I agree  I am a developer by profession  18-24 years old
#
# ...

# %%
ind=data[(data['Country']=="India") & (data['CodingActivities']=="Hobby") & (data['Employment']=="Employed, full-time")]
ind['Age'].value_counts()
# Out:
# Age
# 25-34 years old       224
# 18-24 years old       127
# 35-44 years old        46
# 45-54 years old         3
# Under 18 years old      2
# 55-64 years old         1
# Name: count, dtype: int64

# %%
#548. Finding Information About Developers

#let's find people from your country who are working remotely and who are making salary more than 100K
#all in all we have to combine three conditions here.  first condition is going to be for the country. Then the second condition is for the job type.
#then finally we also have the condition on the salary as well.
#this filter is going to contain all the conditions which we want to specify

filter =(data['Country']=="India") & (data['RemoteWork']=="Remote") & (data['ConvertedCompYearly']>100000)

# %%
data[filter]
# Out:
#        ResponseId     Q120                                         MainBranch  \
# 5410         5411  I agree                     I am a developer by profession
# 10952       10953  I agree                     I am a developer by profession
# 36751       36752  I agree  I am not primarily a developer, but I write co...
# 37842       37843  I agree                     I am a developer by profession
# 39012       39013  I agree                     I am a developer by profession
# 41738       41739  I agree                     I am a developer by profession
# 44275       44276  I agree                     I am a developer by profession
# 46299       46300  I agree                     I am a developer by profession
# 48194       48195  I agree                     I am a developer by profession
# 52813       52814  I agree                     I am a developer by profession
# 58194       58195  I agree                     I am a developer by profession
# ...

# %%
data[filter].LanguageHaveWorkedWith.value_counts()
# this will do is it will go ahead and give you the count so that you will know that. What languages have developers worked with? majorly
# Out:
# LanguageHaveWorkedWith
# C++;HTML/CSS;JavaScript;Python                                                                                                                                                                                                                                                            1
# HTML/CSS;Java;JavaScript;Kotlin;PHP;Python;Rust;SQL                                                                                                                                                                                                                                       1
# C++;Go;Java;JavaScript;Python                                                                                                                                                                                                                                                             1
# ...

# %%
#Now let's say you want to find out from where exactly have they learned to code.
#So in order to find that out, we also have another column here which is called as Learn Code.
data[filter].LearnCode.value_counts()
# Out:
# LearnCode
# Books / Physical media;Other online resources (e.g., videos, blogs, forum)                                                                                                                                                            2
# Books / Physical media;Colleague;Hackathons (virtual or in-person);Online Courses or Certification;On the job training;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);Coding Bootcamp    1
# Books / Physical media;Online Courses or Certification;Other online resources (e.g., videos, blogs, forum);Coding Bootcamp                                                                                                            1
# On the job training;Other online resources (e.g., videos, blogs, forum)                                                                                                                                                               1
# ...

# %%
data[filter].LearnCodeOnline.value_counts()
# Out:
# LearnCodeOnline
# Formal documentation provided by the owner of the tech;Books;Recorded coding sessions;How-to videos;Video-based Online Courses;Written-based Online Courses;Online challenges (e.g., daily or weekly coding challenges);Written Tutorials;Click to write Choice 20;Stack Overflow;Interactive tutorial;Certification videos;Programming Games             1
# Formal documentation provided by the owner of the tech;Blogs with tips and tricks;Books;Recorded coding sessions;How-to videos;Video-based Online Courses;Written Tutorials;Stack Overflow;Certification videos                                                                                                                                           1
# ...

# %%
data[filter].WebframeHaveWorkedWith.value_counts()
# Out:
# WebframeHaveWorkedWith
# React                                                             2
# Laravel;Nuxt.js;Spring Boot;Vue.js                                1
# Node.js;React                                                     1
# Django;Express;FastAPI;Flask;Next.js;Node.js;React;Spring Boot    1
# Angular;jQuery;Spring Boot                                        1
# Node.js;Spring Boot                                               1
# Django;Next.js;React;Svelte                                       1
# Express;Flask;Next.js;Node.js;React;WordPress                     1
# Express;NestJS;Next.js;Node.js;React;Spring Boot                  1
# jQuery;Node.js                                                    1
# NestJS;Node.js;Nuxt.js;Vue.js                                     1
# Name: count, dtype: int64

# %%
#549. Using Survey Schema
data =pd.read_csv('survey_results_public.csv', index_col='ResponseId')
data
# Out:
#                Q120                      MainBranch                 Age  \
# ResponseId
# 1           I agree                   None of these     18-24 years old
# 2           I agree  I am a developer by profession     25-34 years old
# 3           I agree  I am a developer by profession     45-54 years old
# 4           I agree  I am a developer by profession     25-34 years old
# 5           I agree  I am a developer by profession     25-34 years old
# ...             ...                             ...                 ...
# 89180       I agree  I am a developer by profession     25-34 years old
# 89181       I agree  I am a developer by profession     18-24 years old
# 89182       I agree     I code primarily as a hobby   Prefer not to say
# 89183       I agree  I am a developer by profession  Under 18 years old
# 89184       I agree  I am a developer by profession     35-44 years old
#
#                                                    Employment  \
# ResponseId
# ...

# %%
survey=pd.read_csv('survey_results_schema.csv')
survey
# Out:
#        qid        qname                                           question  \
# 0    QID16           S0  <div><span style="font-size:19px;"><strong>Hel...
# 1    QID12     MetaInfo                                  Browser Meta Info
# 2   QID310         Q310  <div><span style="font-size:19px;"><strong>You...
# 3   QID312         Q120
# 4     QID1           S1  <span style="font-size:22px; font-family: aria...
# ..     ...          ...                                                ...
# 73  QID289  Knowledge_7  Waiting on answers to questions often causes i...
# 74  QID289  Knowledge_8  I feel like I have the tools and/or resources ...
# 75  QID290  Frequency_1  Needing help from people outside of your immed...
# 76  QID290  Frequency_2  Interacting with people outside of your immedi...
# 77  QID290  Frequency_3  Encountering knowledge silos (where one indivi...
#
#    force_resp  type selector
# 0       False    DB       TB
# 1       False  Meta  Browser
# ...

# %%
survey.columns
# Out:
# Index(['qid', 'qname', 'question', 'force_resp', 'type', 'selector'], dtype='object')

# %%
#550. Queries To Find Conditional Data

data[data["Country"]=="United States of America"]
# Out:
#                Q120                                         MainBranch  \
# ResponseId
# 2           I agree                     I am a developer by profession
# 3           I agree                     I am a developer by profession
# 4           I agree                     I am a developer by profession
# 7           I agree                     I am a developer by profession
# 8           I agree                     I am a developer by profession
# ...             ...                                                ...
# 89151       I agree  I used to be a developer by profession, but no...
# 89155       I agree                     I am a developer by profession
# 89157       I agree                     I am a developer by profession
# 89176       I agree                     I am a developer by profession
# 89179       I agree                     I am a developer by profession
#
#                         Age           Employment  \
# ResponseId
# ...

# %%
#data[data["Country"]=="United States of America"]
data.query('Country=="United States of America"')
# this makes more sense whenever we have to go ahead and combine multiple conditions together.
# Out:
#                Q120                                         MainBranch  \
# ResponseId
# 2           I agree                     I am a developer by profession
# 3           I agree                     I am a developer by profession
# 4           I agree                     I am a developer by profession
# 7           I agree                     I am a developer by profession
# 8           I agree                     I am a developer by profession
# ...             ...                                                ...
# 89151       I agree  I used to be a developer by profession, but no...
# 89155       I agree                     I am a developer by profession
# 89157       I agree                     I am a developer by profession
# 89176       I agree                     I am a developer by profession
# 89179       I agree                     I am a developer by profession
#
#                         Age           Employment  \
# ResponseId
# ...

# %%
#Let's say here you want to find developers from India who work remotely, who also have an experience
#less than 12 years and still make more than $100,000.
# this is a complicated query wherein you almost have more than three conditions here.
data.query('ConvertedCompYearly>100000 & Country=="India" & RemoteWork=="Remote" & YearsCodePro=="8"')
# Out:
#                Q120                      MainBranch              Age  \
# ResponseId
# 48195       I agree  I am a developer by profession  25-34 years old
#
#                      Employment RemoteWork  \
# ResponseId
# 48195       Employed, full-time     Remote
#
#                                              CodingActivities  \
# ResponseId
# 48195       Hobby;Contribute to open-source projects;Boots...
#
#                                                     EdLevel  \
# ResponseId
# 48195       Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                                     LearnCode  \
# ResponseId
# 48195       Books / Physical media;Online Courses or Certi...
#
#                                               LearnCodeOnline  \
# ResponseId
# 48195       Formal documentation provided by the owner of ...
#
#            LearnCodeCoursesCert YearsCode YearsCodePro   DevType  \
# ResponseId
# 48195         Udemy;Pluralsight        17            8  Educator
#
# ...

# %%
#to convert a specific column into an integer column, what you have to do is you have to use a method called as two numeric.
data['YearsCodePro']=pd.to_numeric(data['YearsCodePro'],errors='coerce')
#Now what this does is that if there is some error in converting that value, then it won't cause a program


#Now what this does is that if there is some error in converting that value, then it won't cause a program
#So once we do this now this gives us the integer values or the converted integer values.
#Then we have to go ahead and take the actual data of yours Code Pro, and save these new values in it.
#And if you run this now this entire data column of yours, Code Pro is now converted into a numeric column
data.query('ConvertedCompYearly>100000 & Country=="India" & RemoteWork=="Remote" & YearsCodePro<12')
# Out:
#                Q120                                         MainBranch  \
# ResponseId
# 5411        I agree                     I am a developer by profession
# 36752       I agree  I am not primarily a developer, but I write co...
# 44276       I agree                     I am a developer by profession
# 48195       I agree                     I am a developer by profession
# 76024       I agree                     I am a developer by profession
# 86253       I agree                     I am a developer by profession
#
#                         Age           Employment RemoteWork  \
# ResponseId
# 5411        25-34 years old  Employed, full-time     Remote
# 36752       25-34 years old  Employed, full-time     Remote
# 44276       25-34 years old  Employed, full-time     Remote
# 48195       25-34 years old  Employed, full-time     Remote
# 76024       25-34 years old  Employed, full-time     Remote
# 86253       25-34 years old  Employed, full-time     Remote
#
# ...

# %%
#So in order to analyze this, let's first go ahead and save these results into something.So sample devs are these.
sample_devs =data.query('ConvertedCompYearly>100000 & Country=="India" & RemoteWork=="Remote" & YearsCodePro<12')
# I want to find out what all languages have they worked with, what all web frameworks they have worked with, so on and so forth.
#So in order to find that out here, let's take a look at the columns.And out of these columns, uh, let's say languages have worked with.

# %%
sample_devs['LanguageHaveWorkedWith'].value_counts()
# Out:
# LanguageHaveWorkedWith
# C++;HTML/CSS;JavaScript;Python                    1
# C++;Go;Java;JavaScript;Python                     1
# JavaScript;TypeScript                             1
# HTML/CSS;Java;JavaScript;Python;SQL;TypeScript    1
# HTML/CSS;Java;JavaScript                          1
# HTML/CSS;JavaScript;TypeScript                    1
# Name: count, dtype: int64

# %%
#let's say you want to find out what web frameworks do they work with.
sample_devs['WebframeHaveWorkedWith'].value_counts()
# Out:
# WebframeHaveWorkedWith
# Node.js;React                                                     1
# Django;Express;FastAPI;Flask;Next.js;Node.js;React;Spring Boot    1
# React                                                             1
# Django;Next.js;React;Svelte                                       1
# jQuery;Node.js                                                    1
# NestJS;Node.js;Nuxt.js;Vue.js                                     1
# Name: count, dtype: int64

# %%
#Now let's say you want to find out which operating systems do these developers actually use.
#So in order to find that out you could go ahead and select this column which is Opsis professional use.
sample_devs['OpSysProfessional use'].value_counts()
# Out:
# OpSysProfessional use
# MacOS                                                   3
# Arch;Debian;Other Linux-based;Red Hat;Ubuntu;Windows    1
# MacOS;Ubuntu                                            1
# Name: count, dtype: int64

# %%
#Now, let's say you also want to find out which tech platforms have they worked with.
#So there's another column for that as well which is platforms have worked with
sample_devs['PlatformHaveWorkedWith'].value_counts()
# Out:
# PlatformHaveWorkedWith
# Amazon Web Services (AWS);Google Cloud                                 2
# Amazon Web Services (AWS);Cloudflare;Digital Ocean;Google Cloud;OVH    1
# Amazon Web Services (AWS);Microsoft Azure                              1
# Google Cloud;Netlify                                                   1
# Name: count, dtype: int64

# %%
#551. Finding Maximum Salary

#let's say we want to find out the maximum salary of a developer who has submitted this particular survey right here.
#So this might actually give us an idea about how much exactly a developer can actually make working
#I want to find out the maximum out of this I could say dot max.
data['ConvertedCompYearly'].max()
# Out:
# np.float64(74351432.0)

# %%
#obviously no developer could be paid $74 million unless and until they are actually the owner of a business, so on and so forth.
# these data seems fake
#So what we could do is we could go ahead and first remove this person who is actually submitted this salary as $74 million.
#So in order to remove this, what we could do is we could save this into a variable called as max underscore salary or max underscore value.

# %%
#So once I have the max value what I could do is I could go ahead and find out the second highest salary which is possible
#So in order to go ahead and find out the second highest salary possible, what I could do is I could
max_data=data['ConvertedCompYearly'].max()
#So this will go ahead and give me the second highest salary right now.
data[data['ConvertedCompYearly']<max_data]
#So this is going to give me the entire details of that person.
# Out:
#                Q120                      MainBranch              Age  \
# ResponseId
# 2           I agree  I am a developer by profession  25-34 years old
# 3           I agree  I am a developer by profession  45-54 years old
# 4           I agree  I am a developer by profession  25-34 years old
# 5           I agree  I am a developer by profession  25-34 years old
# 6           I agree  I am a developer by profession  35-44 years old
# ...             ...                             ...              ...
# 89163       I agree  I am a developer by profession  35-44 years old
# 89167       I agree  I am a developer by profession  18-24 years old
# 89168       I agree  I am a developer by profession  18-24 years old
# 89171       I agree  I am a developer by profession  25-34 years old
# 89172       I agree  I am a developer by profession  25-34 years old
#
#                                                    Employment  \
# ResponseId
# ...

# %%
#But let's suppose if I only want to get the converted comp for that person, I have to say this of converted

second_highest= data[data['ConvertedCompYearly']<max_data]['ConvertedCompYearly']

#So now when you print up the second highest what happens is it gives you a whole bunch of other rows
second_highest
# Out:
# ResponseId
# 2        285000.0
# 3        250000.0
# 4        156000.0
# 5         23456.0
# 6         96828.0
#            ...
# 89163     50719.0
# 89167     16917.0
# 89168     15752.0
# 89171     64254.0
# 89172     61041.0
# Name: ConvertedCompYearly, Length: 48018, dtype: float64

# %%
second_highest= data[data['ConvertedCompYearly']<max_data]['ConvertedCompYearly'].max()
second_highest
# Out:
# np.float64(73607918.0)

# %%
#So we have to find out a way using which we could remove such outlier data from our data set so that we could get an accurate result.

# %%
#552. Removing Outliers
second_highest= data[data['ConvertedCompYearly']<max_data]['ConvertedCompYearly']
second_highest
#So even before removing outliers let's do one thing here. And that is to go ahead and find out what exactly are the salaries which are given by the developers
#If I now go ahead and take a look at the salaries.All the salaries are not ordered in a proper way.So I would say dot sort underscore values.
second_highest.sort_values(ascending=False)
# Out:
# ResponseId
# 77849    73607918.0
# 66224    72714292.0
# 28122    57513831.0
# 19680    36573181.0
# 55103    17612921.0
#             ...
# 63214           1.0
# 5725            1.0
# 87481           1.0
# 64956           1.0
# 37161           1.0
# Name: ConvertedCompYearly, Length: 48018, dtype: float64

# %%
#Now obviously if they are stock options and if they actually went up, then that could be the compensation.
#But here we only want to include the actual pay and not the stock options here.
#So now the question is how would you remove these values from here.
#Even if we take a look at the first 20 salaries, all the salaries here are ridiculous. So we have salaries up to 3 million here.
second_highest.sort_values(ascending=False).head(20)
# Out:
# ResponseId
# 77849    73607918.0
# 66224    72714292.0
# 28122    57513831.0
# 19680    36573181.0
# 55103    17612921.0
# 80587    11000000.0
# 83680    10319366.0
# 47798     9915585.0
# 88348     9203683.0
# 64973     9070484.0
# 771       9000000.0
# 34997     7435143.0
# 66758     6377931.0
# 69890     6229051.0
# 81961     5354477.0
# 79950     4451577.0
# 56805     3508749.0
# 88904     3000000.0
# 10519     2875692.0
# 51183     2700000.0
# Name: ConvertedCompYearly, dtype: float64

# %%
#So let's first go ahead and understand what exactly a percentile is and how that could be used to remove outliers
#So in order to understand percentile let's take a look at this data which we have up over here.
#Now, in order to find this out, what we could do is we could simply go ahead and say data of convertedcom Yearly So here we say dot quantile.
#And to this quantile function I need to pass in 0.95. So what we are essentially doing here is that we are using percentile.
#And we are trying to find out what all salaries are above 95 percentile, which means that which are the people who are making more than 95% 
#of the people which we have here.

data['ConvertedCompYearly'].quantile(0.95)
#So if we run this, as you can see, this is the salary which comes under 95 percentile and this salary is about 230 K per year, which is quite feasible.
#
# Out:
# np.float64(230000.0)

# %%
#So let's suppose we want to find out which salaries are above 99.8 percentile.
data['ConvertedCompYearly'].quantile(0.998)
#So if we do this now this salary comes out to be around $800,000 which is also a feasible salary as a software developer.
#So if you have a lot of experience, then making 800 K is all right as well.
# Out:
# np.float64(800000.0)

# %%
#Now let's suppose here we check for salaries which are in the 99.9% percentile.So that salary comes out to be $1.2 million a year.
data['ConvertedCompYearly'].quantile(0.999)
#Now, even this salary is quite feasible for a senior developer working at a larger company.
#
# Out:
# np.float64(1200000.0)

# %%
#So we are keeping this percentile value on an assumption that the maximum salary of a person could be
#So now once we have this particular figure, we are sure that, all right, even if we ignore the rest
#of the salaries which are above this percentile, that means we are actually removing outliers from our data set.
#So once we have this particular figure, what we could do is we could set this thing as the max salary.
max_salary =data['ConvertedCompYearly'].quantile(0.999)
#So now once we have the max salary, now what we do is we check all the rows which are actually outliers.
#So here I would say data where data of converted comp yearly is going to be greater than the max salary.

data[data['ConvertedCompYearly']>max_salary]
# Out:
#                Q120                                         MainBranch  \
# ResponseId
# 771         I agree                     I am a developer by profession
# 5905        I agree                     I am a developer by profession
# 7487        I agree                     I am a developer by profession
# 7995        I agree                     I am a developer by profession
# 9394        I agree                     I am a developer by profession
# 10519       I agree                     I am a developer by profession
# 14592       I agree                     I am a developer by profession
# 16082       I agree                     I am a developer by profession
# 16632       I agree                     I am a developer by profession
# 16667       I agree                     I am a developer by profession
# 19680       I agree                     I am a developer by profession
# 20783       I agree                     I am a developer by profession
# ...

# %%
#So if we check this these are the following rows which actually are the outliers in our data set.
#And now what we wish to do is we wish to remove all of these outlier rows from our original data set.
#So in order to remove that we have to create a data frame which do not match this.

data =data[data['ConvertedCompYearly']<max_salary]
#And if I want to exclude these values I would say I want to only get those rows here where the yearly
#If I run this now, all the outliers from our data set are removed.
data['ConvertedCompYearly'].max()
# Out:
# np.float64(1083111.0)

# %%
#So to get that what we have to do is we have to get the data where data of converted comp yearly is going to be equal to this value.
#So where data where data of converted comp yearly is going to be equal equal to, you could either say

data[data['ConvertedCompYearly']==data['ConvertedCompYearly'].max()]
#So if you do this now this will go ahead and give you the data about the person who is making the maximum
# Out:
#                Q120                      MainBranch              Age  \
# ResponseId
# 18472       I agree  I am a developer by profession  25-34 years old
#
#                                                    Employment  \
# ResponseId
# 18472       Employed, full-time;Independent contractor, fr...
#
#                                       RemoteWork  \
# ResponseId
# 18472       Hybrid (some remote, some in-person)
#
#                                              CodingActivities         EdLevel  \
# ResponseId
# 18472       Hobby;Contribute to open-source projects;Boots...  Something else
#
#                                                     LearnCode LearnCodeOnline  \
# ResponseId
# 18472       Books / Physical media;Colleague;Friend or fam...             NaN
#
#             LearnCodeCoursesCert YearsCode  YearsCodePro          DevType  \
# ResponseId
# 18472       Codecademy;Skillsoft        10          11.0  Project manager
#
# ...

# %%
# let's suppose we want to also find out the developers who are making the least amount of salary.
#So in order to do this, doing that is quite simple. simply say data of converted comp yearly dot min.
#So if we do data dot converted comp yearly dot min, let's see what do we get.
data['ConvertedCompYearly'].min()
#So if we do this we get $1 as a salary here.
# Out:
# np.float64(1.0)

# %%
#Now this might be the case because some of the developers might be unemployed or they still might be students who are yet not working.
#Therefore, what we could also do is we could also go ahead and only select those students who are actually working or who are employed.
#So here I could create a new data set called as EMP data, which stands for Employee data.
emp_data=data[data['Employment']=='Employed']
#So now if I go ahead and run this, this will only give me those people who are actually employed.
#And if I run this I get an Nan value here.
emp_data['ConvertedCompYearly'].min()
# Out:
# nan

# %%
#Now let's suppose here you also want to go ahead and exclude all the values which are actually Nan.
import numpy as np
emp_data=data[(data['Employment']=='Employed') & data['ConvertedCompYearly']!=np.nan ]
emp_data['ConvertedCompYearly'].min()
#If I run this now, still, I am getting the salary or the minimum salary as one, 
#which actually might not be true because obviously no developer would be paid $1.
# Out:
# np.float64(1.0)

# %%
#So that means we have the outliers on the lower end as well.
#So that means we need to remove those outliers which are the outliers from the lower salary range.
#So in order to go ahead and find that out here, I would say minimum salary is going to be equal to
#And again we will use the quantile to find out the lowest possible salary.
#And here as we are interested in finding out the lowest I would say I want to search for the salary which has two percentile.
min_salary=emp_data['ConvertedCompYearly'].quantile(0.02)
min_salary
# Out:
# np.float64(1790.26)

# %%
#So let's now go ahead and let's remove all the columns which have salary lower than the minimum salary 
#Because we only want to now deal with people who are employed.
#so MP underscore data where the converted comp yearly should be greater than this minimum salarySo this greater than minimum underscore salary.

data=data[emp_data['ConvertedCompYearly']>min_salary]
# now I could go ahead and find out the minimum salary.
# if we do this right now, as you can see, this is the lowest possible salary for a developer.
data['ConvertedCompYearly'].min()
# Out:
# np.float64(1791.0)

# %%
#And if you want to go ahead and take a look at the minimum salaries offered, what you could do is you could go ahead and say dot sort underscore values.
#Now this will go ahead and give you the actual salaries offered, which are the minimum salaries like

data['ConvertedCompYearly'].sort_values()
# Out:
# ResponseId
# 63237       1791.0
# 76931       1794.0
# 55183       1800.0
# 45118       1800.0
# 33195       1800.0
#            ...
# 67542    1069822.0
# 16304    1070895.0
# 39763    1070895.0
# 42983    1070895.0
# 18472    1083111.0
# Name: ConvertedCompYearly, Length: 47004, dtype: float64

# %%
#553. Finding Mean Salary

#So let's suppose here you want to find out which developers from your country makes the most salary.
#So in order to find that out what we would first do is that first we'll go ahead and only select developers from a specific country.
#So here you could see data of data where the country is going to be equal to.

#So let me save that new data frame into a variable called as Indian underscore devs.
india_devs=data[data['Country']=='India']
india_devs
# Out:
#                Q120                      MainBranch              Age  \
# ResponseId
# 67          I agree  I am a developer by profession  25-34 years old
# 128         I agree  I am a developer by profession  25-34 years old
# 178         I agree  I am a developer by profession  35-44 years old
# 210         I agree  I am a developer by profession  18-24 years old
# 248         I agree  I am a developer by profession  25-34 years old
# ...             ...                             ...              ...
# 89070       I agree  I am a developer by profession  25-34 years old
# 89085       I agree  I am a developer by profession  25-34 years old
# 89106       I agree  I am a developer by profession  18-24 years old
# 89109       I agree  I am a developer by profession  25-34 years old
# 89168       I agree  I am a developer by profession  18-24 years old
#
#                                                    Employment  \
# ResponseId
# ...

# %%
#Now, if I want to go ahead and find out the maximum salary across these developers, then I could say

#So if you run this, as you can see, this is the maximum salary which is around $424,000 per year.
india_devs['ConvertedCompYearly'].max()
# Out:
# np.float64(424091.0)

# %%
##Now let's suppose you want to find out more information about the developer who actually makes this salary
max_india_salary=india_devs['ConvertedCompYearly'].max()

#And once we have this max Indian salary value, we could actually find out the row which actually has that salary
#So in order to find that out here I'll first get access to the Indian devs.
#You could also do this on your main data frame as well, but it kind of makes sense to do it on this dataFrame.
#So where Indian underscore devs salary, where Indian devs converted comp yearly is going to be equal to the max Indian salary.
#So once you do this, this is going to give you only one result wherein the developer salary is equal
#So if you go ahead and run this, as you can see this is the developer we are talking about.
india_devs[india_devs['ConvertedCompYearly']==max_india_salary]
# Out:
#                Q120                      MainBranch              Age  \
# ResponseId
# 72666       I agree  I am a developer by profession  25-34 years old
#
#                      Employment RemoteWork CodingActivities  \
# ResponseId
# 72666       Employed, full-time  In-person            Hobby
#
#                                                  EdLevel  \
# ResponseId
# 72666       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                     LearnCode LearnCodeOnline  \
# ResponseId
# 72666       On the job training;School (i.e., University, ...             NaN
#
#            LearnCodeCoursesCert YearsCode  YearsCodePro            DevType  \
# ResponseId
# 72666                       NaN         8           7.0  Developer, mobile
#
#                        OrgSize      PurchaseInfluence     TechList  \
# ResponseId
# 72666       20 to 99 employees  I have some influence  Investigate
#
# ...

# %%
#Now let's suppose here after finding the maximum salary, let's also go ahead and find out the minimum salary as well
min_india_salary=india_devs['ConvertedCompYearly'].min()
india_devs[india_devs['ConvertedCompYearly']==min_india_salary]
# Out:
#                Q120                                         MainBranch  \
# ResponseId
# 10843       I agree                     I am a developer by profession
# 26854       I agree                     I am a developer by profession
# 43087       I agree                     I am a developer by profession
# 45920       I agree  I am not primarily a developer, but I write co...
# 59200       I agree                     I am a developer by profession
# 68260       I agree                     I am a developer by profession
# 71589       I agree                     I am a developer by profession
# 72851       I agree                     I am a developer by profession
# 72938       I agree                     I am a developer by profession
# 79279       I agree                     I am a developer by profession
#
#                         Age  \
# ResponseId
# 10843       25-34 years old
# 26854       25-34 years old
# 43087       25-34 years old
# 45920       25-34 years old
# ...

# %%
#So if you actually take a look at the salary in local currency, you will be able to find that here.
#So as you can see, the total comp here is around ₹150,000 in local currency.
#Now let's try to go ahead and find out the mean or average salary amongst developers.
#So after knowing the average salary, you could basically compare and contrast how your salary matches up with other developers.
#So here I would say Indian devs and here this is going to be the salary column.
#So the mean value or the mean salary for Indian developers is around $28,000 a year.
india_devs['ConvertedCompYearly'].mean()
# Out:
# np.float64(28316.321864594895)

# %%
##You could also go ahead and convert it locally as well.
india_devs['ConvertedCompYearly'].mean() *80
# this salary is mean of all the developers salary in our data set, and some of the developers
#in this data set might actually have a greater years of experience than yourself.
#So in order to make a fair comparison of your salary with the mean salary, what you could do is you
#could first go ahead and filter out developers on the basis of their years of experience.
#So here I would say take the Indian devs where the Indian devs years of experience.
# Out:
# np.float64(2265305.7491675913)

# %%
#So if you run this, as you can see, this is actually the salary of a developer who has around seven years of experience.
india_devs[india_devs['YearsCodePro']==7]['ConvertedCompYearly'].mean()
# Out:
# np.float64(32871.33)

# %%
#So now let's say here, instead of getting the mean, you want to find out if a person actually has
#seven years of experience, what's the maximum possible salary they could earn?
#So here now we are not comparing with the average salary, but we are comparing with the highest possible salary a person can make with seven years of experience.
#So now if you run this as you can see, the maximum salary someone in India could earn as a developer
india_devs[india_devs['YearsCodePro']==7]['ConvertedCompYearly'].max()
# Out:
# np.float64(424091.0)

# %%
india_devs[india_devs['YearsCodePro']==7]['ConvertedCompYearly'].min()
# Out:
# np.float64(1818.0)

# %%
us_devs=data[data['Country']=="United States of America"]
us_devs['ConvertedCompYearly'].max()
# Out:
# np.float64(1000000.0)

# %%
us_devs['ConvertedCompYearly'].min()
# Out:
# np.float64(2000.0)

# %%
max_us_salary=us_devs['ConvertedCompYearly'].max() 
us_devs[us_devs['ConvertedCompYearly']==max_us_salary]
# Out:
#                Q120                                         MainBranch  \
# ResponseId
# 1858        I agree                     I am a developer by profession
# 7106        I agree                     I am a developer by profession
# 12994       I agree                     I am a developer by profession
# 32009       I agree                     I am a developer by profession
# 34630       I agree                     I am a developer by profession
# 35459       I agree  I am not primarily a developer, but I write co...
# 44861       I agree  I am not primarily a developer, but I write co...
# 49222       I agree                     I am a developer by profession
# 58691       I agree                     I am a developer by profession
#
#                           Age  \
# ResponseId
# 1858          45-54 years old
# 7106          25-34 years old
# 12994         35-44 years old
# 32009       65 years or older
# 34630         25-34 years old
# 35459         25-34 years old
# ...

# %%
min_us_salary=us_devs['ConvertedCompYearly'].min() 
min_us_salary
#but instead you want to calculate average salary on the basis of a language or programming language
#
#So let's suppose you want to find out the average salary of people who use Python.
#us_devs[us_devs['ConvertedCompYearly']==min_us_salary]
# Out:
# np.float64(2000.0)

# %%
us_devs['ConvertedCompYearly'].mean()
# Out:
# np.float64(166951.88493776988)

# %%
data[data['LanguageHaveWorkedWith']=="Python"]['ConvertedCompYearly'].mean()
#So we could conclude that on an average a Python developer actually makes around $90,000 a year.
# Out:
# np.float64(89158.00847457627)

# %%
#554. GroupBy Clause To Find Salaries Across Countries
#So a group by method is used to group a specific set of rows And depending upon something which they might have in common.
#So in the data which we have, in order to find out how much money is actually spent on hiring all the developers, which we actually have here.
#What we could do is we could take all the rows which we have here and simply sum up the values which we have in this converted comp yearly.
#So what I could do here is that I could say, all right, take the entire data frame.
#And then if I just print up the total converted comp here, this is going to give me all the values
data['ConvertedCompYearly']
# Out:
# ResponseId
# 2        285000.0
# 3        250000.0
# 4        156000.0
# 5         23456.0
# 6         96828.0
#            ...
# 89163     50719.0
# 89167     16917.0
# 89168     15752.0
# 89171     64254.0
# 89172     61041.0
# Name: ConvertedCompYearly, Length: 47004, dtype: float64

# %%
data['ConvertedCompYearly'].sum()
# Out:
# np.float64(4461493878.0)

# %%
#Now this information might be useful in some scenario, but let's suppose you want to find out the total
#sum of money which is paid to developers across different countries.
#So in that case, instead of simply performing a sum here, what you could do is you could first group
#the data on the basis of the country and then calculated the sum on the converted comp yearly.
#So in order to do that here I would take the data frame. And then I would now go ahead and create certain groups.
data.groupby('Country')
# So now this group is nothing, but it's simply an object. And you obviously cannot work with it directly.

# %%
#So here if I say dot sum and if I hit enter, it actually is taking a while for this thing to load up.
#Now here what happens is it will take all the columns which we have and basically sum them up.
data.groupby('Country').sum()
# Out:
#                                                                                    Q120  \
# Country
# Afghanistan                                                       I agreeI agreeI agree
# Albania                               I agreeI agreeI agreeI agreeI agreeI agreeI ag...
# Algeria                               I agreeI agreeI agreeI agreeI agreeI agreeI ag...
# Andorra                                             I agreeI agreeI agreeI agreeI agree
# Angola                                                                          I agree
# ...                                                                                 ...
# Venezuela, Bolivarian Republic of...  I agreeI agreeI agreeI agreeI agreeI agreeI ag...
# Viet Nam                              I agreeI agreeI agreeI agreeI agreeI agreeI ag...
# Yemen                                               I agreeI agreeI agreeI agreeI agree
# ...

# %%
#So the columns which we are strings, they actually get appended with each other.
#But let's suppose out of these columns we are only concerned with the converted comp yearly column
#So here I would say all right I want to only access the converted comp yearly column.
#As you can see now, these sums are created only on the basis of these countries right here.
data.groupby('Country').sum()['ConvertedCompYearly']
# Out:
# Country
# Afghanistan                               72691.0
# Albania                                  584078.0
# Algeria                                  207091.0
# Andorra                                  601844.0
# Angola                                     7942.0
#                                           ...
# Venezuela, Bolivarian Republic of...    1243292.0
# Viet Nam                                2378703.0
# Yemen                                     89036.0
# Zambia                                   138373.0
# Zimbabwe                                 267400.0
# Name: ConvertedCompYearly, Length: 169, dtype: float64

# %%
#Now, this data still might not make a whole bunch of sense here because it's actually organized alphabetically.
#But let's suppose here you want to arrange it in a descending order so as to get a view of which country makes the most in terms of developer salaries.
#So here I could go ahead and say sort underscore values and set the ascending equals false.
data.groupby('Country').sum()['ConvertedCompYearly'].sort_values(ascending=False)
# Out:
# Country
# United States of America                                1.971869e+09
# United Kingdom of Great Britain and Northern Ireland    3.365645e+08
# Germany                                                 3.260660e+08
# Canada                                                  2.162094e+08
# Australia                                               1.264100e+08
#                                                             ...
# Gabon                                                   6.532000e+03
# Antigua and Barbuda                                     5.791000e+03
# Togo                                                    3.920000e+03
# Cape Verde                                              2.914000e+03
# Burundi                                                 2.500000e+03
# Name: ConvertedCompYearly, Length: 169, dtype: float64

# %%
#So you could go ahead and decode these numbers.
#So by looking at this data you could know that how much of the money in terms of salaries is paid to developers, in which countries.


#Now let's suppose here, instead of grouping people as per their countries, let's suppose you want to group people on the basis of their working status.
#That is, if they work remotely or hybrid, or if they work full time from an office.
#So here, instead of grouping the data on the basis of the country, now I could go ahead and group
#And now if I go ahead and add a remote work here, and if I run this again, it's going to take a while
data.groupby('RemoteWork').sum()['ConvertedCompYearly'].sort_values(ascending=False)
# Out:
# RemoteWork
# Remote                                  2.200225e+09
# Hybrid (some remote, some in-person)    1.818625e+09
# In-person                               4.363542e+08
# Name: ConvertedCompYearly, dtype: float64

# %%
#how many number of people are working remotely, how many of them are working hybrid or in person
#So in that case, you could say data of remote work.
#Now if you do this, this is going to give you this response right here.
data['RemoteWork']
#butt right now if I say dot value underscore counts, then this will give you an idea that about 20,000
# Out:
# ResponseId
# 2                                      Remote
# 3        Hybrid (some remote, some in-person)
# 4        Hybrid (some remote, some in-person)
# 5                                      Remote
# 6                                      Remote
#                          ...
# 89163                                  Remote
# 89167                               In-person
# 89168                                  Remote
# 89171    Hybrid (some remote, some in-person)
# 89172                               In-person
# Name: RemoteWork, Length: 47004, dtype: object

# %%
data['RemoteWork'].value_counts()
# Out:
# RemoteWork
# Remote                                  20696
# Hybrid (some remote, some in-person)    19976
# In-person                                6267
# Name: count, dtype: int64

# %%
#555. Visualising Education Level On Matplotlib Plot

#Now you want to go ahead and take a look at the education level of the developers, which we have here.
#So as you can see there are multiple education levels here like bachelor's degree, master's degree,
#So in order to get that information here, I would say data of which is going to be the column name,
data['EdLevel']
# Out:
# ResponseId
# 2             Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3             Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4             Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 5             Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 6        Some college/university study without earning ...
#                                ...
# 89163      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 89167    Some college/university study without earning ...
# 89168         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 89171      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 89172      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# Name: EdLevel, Length: 47004, dtype: object

# %%
#And if I go ahead and print this thing up, as you can see there are multiple responses here.
#Now if I want to get the number of responses here, I would say dot value underscore counts.
data['EdLevel'].value_counts()
# Out:
# EdLevel
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          22024
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                       12866
# Some college/university study without earning a degree                                 5507
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                         2250
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     2111
# Associate degree (A.A., A.S., etc.)                                                    1562
# Something else                                                                          480
# Primary/elementary school                                                               204
# Name: count, dtype: int64

# %%
#Now let's suppose you want to go ahead and plot this particular data onto a graph.
#Then in that particular case you have to use matplotlib.
#But let's suppose whenever you want to go ahead and plot this data on a graph, you want to calculate the percentage value here.
#So in order to calculate the percentage spread of these education level here I would say normalize and I would set the normalize to true.
data['EdLevel'].value_counts(normalize=True) *100
# Out:
# EdLevel
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          46.855587
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                       27.372139
# Some college/university study without earning a degree                                11.716024
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                         4.786827
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     4.491107
# Associate degree (A.A., A.S., etc.)                                                    3.323121
# Something else                                                                         1.021190
# Primary/elementary school                                                              0.434006
# Name: proportion, dtype: float64

# %%
#So in order to get the actual percentages you need to multiply it with 100.
#So here 46% of the people have a bachelor's degree, 27% of them have a master's degree.
#So now let's go ahead and let's plot this data on a matplotlib plot.

# %%
from matplotlib import pyplot as plt
percentage_spread=data['EdLevel'].value_counts(normalize=True) *100
percentage_spread.plot(kind='barh')
plt.title('distribution of education levels')
plt.xlabel('Percentage')
plt.ylabel('Education Level')
plt.grid()
plt.show()
#So here the series name is percent underscore spread and then simply say dot plot.
#Now this will actually go ahead and simply plot that up over here on a graph.
#Now here we want the type of graph to be a bar graph in a horizontal fashion.
#So here I would say kind equals that's going to be bar h which stands for bar and horizontal.
#Now after doing this let's also set the title for the plot as well.
#And this plot is going to be about the distribution of education levels.
#Now let's go ahead and let's set the x label and y label of the graph.
#So here this data which we have up over here on the x label we are going to have the percentage values.

# %%
#Now it actually makes sense to go ahead and kind of rearrange this in a descending order.
#So in order to do that here, I could also go ahead and kind of sort this percentage spread.
percentage_spread=data['EdLevel'].value_counts(normalize=True) *100
percentage_spread=percentage_spread.sort_values()
percentage_spread.plot(kind='barh')
plt.title('distribution of education levels')
plt.xlabel('Percentage')
plt.ylabel('Education Level')
plt.grid()
plt.show()
#And if I do that, as you can see now the values are sorted in a descending order.

# %%
#556. Calculating Offline Learning Percentage Share

#let's learn how to represent the data about from where the developers actually learn to code on a matplotlib plot.
#So first of all, we have to extract that data and analyze that data from the data frame which we have
#So if I say data of learn code and if I run this as you can see there are multiple responses.
data['LearnCode'].value_counts()
# Out:
# LearnCode
# Other online resources (e.g., videos, blogs, forum)                                                                                                                                                                                    1926
# Books / Physical media;Online Courses or Certification;On the job training;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc)                                                                 1667
# Books / Physical media;Other online resources (e.g., videos, blogs, forum)                                                                                                                                                             1571
# Books / Physical media;Online Courses or Certification;Other online resources (e.g., videos, blogs, forum)                                                                                                                             1550
# ...

# %%
#Having these many options is a little bit confusing, and that's because every developer can actuall select multiple options here.
#For example, a particular developer does not only have one source for learning, but they actually have multiple sources.
#So now the question is how exactly can we go ahead and get the unique values which we might have up
#So one thing to notice here is that if you access the data for a single developer, these values which
#So what we could do here is that first of all, we could go ahead and take this data, which we have,
#and then split this data on the basis of the colon which we have.
#So in order to do this here, instead of saying dot value counts, I would say dot str dot split andI would split on the basis of the colon which I have.
#
#So now if I go ahead and run this, as you can see now here, instead of getting a string in which the
data['LearnCode'].str.split(";")
# Out:
# ResponseId
# 2        [Books / Physical media, Colleague, Friend or ...
# 3        [Books / Physical media, Colleague, On the job...
# 4        [Colleague, Friend or family member, Other onl...
# 5        [Books / Physical media, Online Courses or Cer...
# 6        [Books / Physical media, Colleague, Online Cou...
#                                ...
# 89163    [On the job training, Other online resources (...
# 89167    [Books / Physical media, Hackathons (virtual o...
# 89168    [Online Courses or Certification, Other online...
# 89171    [Colleague, Hackathons (virtual or in-person),...
# 89172    [Other online resources (e.g., videos, blogs, ...
# Name: LearnCode, Length: 47004, dtype: object

# %%
# have multiple values here kind of spread across that user.
#So in order to do that we'll use a method called as explode.
#So if I say explode on this one now instead of one user having a single list and then having multiple
data['LearnCode'].str.split(";").explode()
# Out:
# ResponseId
# 2                                   Books / Physical media
# 2                                                Colleague
# 2                                  Friend or family member
# 2                        Hackathons (virtual or in-person)
# 2                          Online Courses or Certification
#                                ...
# 89171                                  On the job training
# 89171    Other online resources (e.g., videos, blogs, f...
# 89171              School (i.e., University, College, etc)
# 89172    Other online resources (e.g., videos, blogs, f...
# 89172              School (i.e., University, College, etc)
# Name: LearnCode, Length: 163771, dtype: object

# %%
#And for response ID two here, now we have multiple options spread across like this.
#So now what happens is once we have this data scattered around now we could finally go ahead and we
#So let me go ahead and save this data into a variable called as learn underscore methods.
learn_methods=data['LearnCode'].str.split(";").explode()
learn_methods.value_counts()
#So now what happens is if I run this as you can see now we have all the responses separated out in a single object.
# Out:
# LearnCode
# Other online resources (e.g., videos, blogs, forum)    37689
# On the job training                                    25880
# Books / Physical media                                 25456
# School (i.e., University, College, etc)                23656
# Online Courses or Certification                        23190
# Colleague                                              12800
# Friend or family member                                 4699
# Coding Bootcamp                                         3959
# Hackathons (virtual or in-person)                       3543
# Other (please specify):                                 2817
# Name: count, dtype: int64

# %%
#So here as you can see there are about 37,687 responses who have stated other online resources like
#So here in order to find out the percentage I would say normalize and set it to true.
learn_methods.value_counts(normalize=True) * 100
# Out:
# LearnCode
# Other online resources (e.g., videos, blogs, forum)    23.024760
# On the job training                                    15.810470
# Books / Physical media                                 15.551442
# School (i.e., University, College, etc)                14.451796
# Online Courses or Certification                        14.167110
# Colleague                                               7.819707
# Friend or family member                                 2.870688
# Coding Bootcamp                                         2.418611
# Hackathons (virtual or in-person)                       2.164470
# Other (please specify):                                 1.720946
# Name: proportion, dtype: float64

# %%
#But technically we want to calculate the percentage based on the total number of respondents.
#So if I say method underscore counts I actually get these values here and now in order to go ahead and
method_counts=learn_methods.value_counts()
method_counts
# Out:
# LearnCode
# Other online resources (e.g., videos, blogs, forum)    37689
# On the job training                                    25880
# Books / Physical media                                 25456
# School (i.e., University, College, etc)                23656
# Online Courses or Certification                        23190
# Colleague                                              12800
# Friend or family member                                 4699
# Coding Bootcamp                                         3959
# Hackathons (virtual or in-person)                       3543
# Other (please specify):                                 2817
# Name: count, dtype: int64

# %%
#calculate the percentage spread across each one of them, I would divide the entire values, which I
#have with 89,184, because those are the number of developers who have submitted the survey.
#And after dividing this value with 89,000 and multiplying with 100, I could finally go ahead and find out how many percentage of people have actually selected this as the learning resource.
#So here, in order to go ahead and perform or calculate the method percentage on all the values here,
#I could simply go ahead and say method underscore percentages equals method counts and divide it with the number of respondents which we have.
#So we have 89,184 entries because we have these many number of rows.
#So let's include this in parentheses because we also have to multiply this with 100.So I'll include that and then multiply this with 100.
method_percentages =(method_counts / 89184) *100
method_percentages
# Out:
# LearnCode
# Other online resources (e.g., videos, blogs, forum)    42.259822
# On the job training                                    29.018658
# Books / Physical media                                 28.543236
# School (i.e., University, College, etc)                26.524937
# Online Courses or Certification                        26.002422
# Colleague                                              14.352350
# Friend or family member                                 5.268882
# Coding Bootcamp                                         4.439137
# Hackathons (virtual or in-person)                       3.972686
# Other (please specify):                                 3.158638
# Name: count, dtype: float64

# %%
#So now once we have these method percentage values, let's now finally go ahead and let's display this on a matplotlib plot.
from matplotlib import pyplot as plt
#And also let's go ahead and let's sort this up as well.
#So over here I could go ahead and say method underscore percentages equals method underscore percentages
method_percentages=method_percentages.sort_values()
method_percentages.plot(kind='barh')
plt.title('Learning Methods')
plt.xlabel('percentage')
plt.ylabel('LearnCode')
plt.grid()

# %%
 #we don't know how much percentage this figure right here exactly is
#So in order to solve this problem, what you could do is you could also go ahead and add certain labels for each row which you have here.
#So in order to do this, what you could do is you could go ahead and loop through the already existing
method_percentages=method_percentages.sort_values()
method_percentages.plot(kind='barh')
plt.title('Learning Methods')
plt.xlabel('percentage')
plt.ylabel('LearnCode')
plt.grid()
for index, value in enumerate (method_percentages):
    plt.text(value,index, f'{value:.2f}%')
plt.show()

# %%
method_percentages=method_percentages.sort_values()
method_percentages.plot(kind='barh')
plt.title('Learning Methods')
plt.xlabel('percentage')
plt.ylabel('LearnCode')
plt.grid()
for index, value in enumerate (method_percentages):
    plt.text(value,index, f'{value:.2f}%', va ='center')  #So if you run this as you can see now the values are aligned properly to the center.
plt.show()

# %%
#557. Calculating Online Learning Percentage Share

# let's find out the percentage spread across multiple online learning methods.

data
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
#So here I would say data of let's say learn code online.
data['LearnCodeOnline'].value_counts()
# Out:
# LearnCodeOnline
# Formal documentation provided by the owner of the tech;Blogs with tips and tricks;Written Tutorials;Click to write Choice 20;Stack Overflow                                                                                                                                                                                               1182
# Formal documentation provided by the owner of the tech;Blogs with tips and tricks;Written Tutorials;Stack Overflow                                                                                                                                                                                                                         977
# ...

# %%
#you can see here, there are multiple methods suggested by a single user.
data['LearnCodeOnline'].str.split(";")
# Out:
# 0                                                      NaN
# 1        [Formal documentation provided by the owner of...
# 2        [Formal documentation provided by the owner of...
# 3        [Formal documentation provided by the owner of...
# 4        [Formal documentation provided by the owner of...
#                                ...
# 89179    [Formal documentation provided by the owner of...
# 89180    [Formal documentation provided by the owner of...
# 89181                                                  NaN
# 89182    [Formal documentation provided by the owner of...
# 89183    [Formal documentation provided by the owner of...
# Name: LearnCodeOnline, Length: 89184, dtype: object

# %%
online_methods=data['LearnCodeOnline'].str.split(";").explode()
#Now once we have the online methods now we wish to go ahead and calculate the different counts for different
#So here I would say online underscore methods dot value counts.
online_methods.value_counts()
# Out:
# LearnCodeOnline
# Formal documentation provided by the owner of the tech         63329
# Stack Overflow                                                 57861
# Blogs with tips and tricks                                     53745
# How-to videos                                                  42149
# Written Tutorials                                              42012
# Video-based Online Courses                                     34629
# Books                                                          30432
# Click to write Choice 20                                       29780
# Written-based Online Courses                                   25309
# Recorded coding sessions                                       19690
# Interactive tutorial                                           18242
# Online challenges (e.g., daily or weekly coding challenges)    15544
# Certification videos                                            9326
# ...

# %%
#So once we have the online method counts let's go ahead and let's calculate their percentages.
online_method_counts=online_methods.value_counts()
online_methods_percentages= (online_method_counts/89184) * 100
#So once we have the online method counts let's go ahead and let's calculate their percentages.
online_methods_percentages
# Out:
# LearnCodeOnline
# Formal documentation provided by the owner of the tech         71.009374
# Stack Overflow                                                 64.878229
# Blogs with tips and tricks                                     60.263052
# How-to videos                                                  47.260719
# Written Tutorials                                              47.107104
# Video-based Online Courses                                     38.828714
# Books                                                          34.122713
# Click to write Choice 20                                       33.391640
# Written-based Online Courses                                   28.378409
# Recorded coding sessions                                       22.077951
# Interactive tutorial                                           20.454342
# Online challenges (e.g., daily or weekly coding challenges)    17.429135
# Certification videos                                           10.457033
# ...

# %%
#So now our next task is to go ahead and plot this information on a matplotlib plot.
from matplotlib import pyplot as plt
online_methods_percentages=online_methods_percentages.sort_values()
online_methods_percentages.plot(kind='barh')
plt.title('Online Learning Methods')
plt.xlabel('percentage')
plt.ylabel('Learn Code with Online methods')
plt.grid()
for index, value in enumerate (online_methods_percentages):
    plt.text(value,index, f'{value:.2f}%', va ='center')  #So if you run this as you can see now the values are aligned properly to the center.
plt.show()

# %%
#So now let's say we want to find out which online course platforms do developers use the most to learn from
#So in order to find that out, we need to go ahead and explore our data frame and find out if any column gives us that information.


#558. Calculating Online Learning Platform's Percentage Share
# find out the different online learning platforms developers
data['LearnCodeCoursesCert'].value_counts()
# Out:
# LearnCodeCoursesCert
# Udemy                                                 7445
# Other                                                 3230
# Udemy;Coursera                                        2612
# Udemy;Pluralsight                                     1958
# Codecademy;Udemy                                      1837
#                                                       ...
# Other;Udemy;Pluralsight;Coursera;Skillsoft               1
# Codecademy;edX;Udemy;Pluralsight;Udacity;Skillsoft       1
# edX;Coursera;Udacity;Skillsoft                           1
# Other;Codecademy;Udemy;Udacity;Skillsoft                 1
# Other;Codecademy;Pluralsight;Coursera;Udacity            1
# Name: count, Length: 210, dtype: int64

# %%
#So what we could do here is that we could first go ahead and find out how many number of people actually
import numpy as np
online_methos_responses= data[data['LearnCodeCoursesCert']!=np.nan]
response_counts=online_methos_responses['LearnCodeCoursesCert'].count()
response_counts
# Out:
# np.int64(37076)

# %%
online_platform=data['LearnCodeCoursesCert'].str.split(";").explode()

# %%
online_platform_counts=data['LearnCodeCoursesCert'].str.split(";").explode().value_counts()
online_platform_counts
# Out:
# LearnCodeCoursesCert
# Udemy          24296
# Coursera       12836
# Codecademy      9015
# Pluralsight     8463
# Other           7811
# edX             5536
# Udacity         3992
# Skillsoft        754
# Name: count, dtype: int64

# %%
online_platform_percentage=(online_platform_counts/response_counts) *100
online_platform_percentage
# Out:
# LearnCodeCoursesCert
# Udemy          65.530262
# Coursera       34.620779
# Codecademy     24.314921
# Pluralsight    22.826087
# Other          21.067537
# edX            14.931492
# Udacity        10.767073
# Skillsoft       2.033661
# Name: count, dtype: float64

# %%
from matplotlib import pyplot as plt
online_platform_percentags=online_platform_percentage.sort_values()
online_platform_percentage.plot(kind='barh')
plt.title('Online Platform')
plt.xlabel('percentage')
plt.ylabel('Learn Code Online Platform')
plt.grid()
for index, value in enumerate (online_platform_percentage):
    plt.text(value,index, f'{value:.2f}%', va ='center')  #So if you run this as you can see now the values are aligned properly to the center.
plt.show()
